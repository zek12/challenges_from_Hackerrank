# %%
def sockMerchant(n, ar):
    # Write your code here
    s = set()
    res = 0
    for elem in ar:
      if elem in s:
        s.remove(elem)
        res += 1
      else:
        s.add(elem)
    
    return(res)

# %%
n = 9
ar = [10, 20, 20, 10, 10, 30, 50, 10, 20]
sockMerchant(n, ar)
# Out:
# 3

# %%
n = 7
ar = [1, 2, 1, 2, 1, 3, 2]
sockMerchant(n, ar)
# Out:
# 2
